# %%
from ipynb.fs.full.ParkingSpaceDetector import *
import random
import glob

path = 'E:\\OneDrive - UNIVERSIDAD DE HUELVA\TFG\PKLot\PKLot\PKLot\\UFPR05'

files = glob.glob(path+ '/**/*.jpg', recursive=True)            # Get all images in path
selected_files = random.choices(files, k=int(len(files)/10))    # Select n random images from dataset

# %%
#WITHOUT GAUSSIAN_BLUR
params = DetectionParams(None, 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 33, 9, 3, 20) # UPR05
detect_batch(selected_files, params,k=0.2, showImshow=False, setup=False)
# Out:
# 415/415:  E:\OneDrive - UNIVERSIDAD DE HUELVA\TFG\PKLot\PKLot\PKLot\UFPR05\Sunny\2013-14-16\2013-04-16_06_30_00.jpg
# Precision: 0.895
# Recall: 0.642
# F1 Score: 0.748
# Accuracy: 0.825

# %%
params = DetectionParams((3,3), 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 33, 9, 3, 20) # UPR05
detect_batch(selected_files, params,k=0.2, showImshow=False, setup=False)
# Out:
# 415/415:  E:\OneDrive - UNIVERSIDAD DE HUELVA\TFG\PKLot\PKLot\PKLot\UFPR05\Sunny\2013-14-16\2013-04-16_06_30_00.jpg
# Precision: 0.886
# Recall: 0.703
# F1 Score: 0.784
# Accuracy: 0.843

# %%
params = DetectionParams((5,5), 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 33, 9, 3, 20) # UPR05
detect_batch(selected_files, params,k=0.2, showImshow=False, setup=False)
# Out:
# 415/415:  E:\OneDrive - UNIVERSIDAD DE HUELVA\TFG\PKLot\PKLot\PKLot\UFPR05\Sunny\2013-14-16\2013-04-16_06_30_00.jpg
# Precision: 0.874
# Recall: 0.756
# F1 Score: 0.811
# Accuracy: 0.857

# %%
params = DetectionParams((7,7), 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 33, 9, 3, 20) # UPR05
detect_batch(selected_files, params,k=0.2, showImshow=False, setup=False)
# Out:
# 415/415:  E:\OneDrive - UNIVERSIDAD DE HUELVA\TFG\PKLot\PKLot\PKLot\UFPR05\Sunny\2013-14-16\2013-04-16_06_30_00.jpg
# Precision: 0.853
# Recall: 0.841
# F1 Score: 0.847
# Accuracy: 0.877

# %%
params = DetectionParams((9,9), 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 33, 9, 3, 20) # UPR05
detect_batch(selected_files, params,k=0.2, showImshow=False, setup=False)
# Out:
# 415/415:  E:\OneDrive - UNIVERSIDAD DE HUELVA\TFG\PKLot\PKLot\PKLot\UFPR05\Sunny\2013-14-16\2013-04-16_06_30_00.jpg
# Precision: 0.830
# Recall: 0.890
# F1 Score: 0.859
# Accuracy: 0.882

# %%
params = DetectionParams((15,15), 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 33, 9, 3, 20) # UPR05
detect_batch(selected_files, params,k=0.2, showImshow=False, setup=False)
# Out:
# 415/415:  E:\OneDrive - UNIVERSIDAD DE HUELVA\TFG\PKLot\PKLot\PKLot\UFPR05\Sunny\2013-14-16\2013-04-16_06_30_00.jpg
# Precision: 0.728
# Recall: 0.978
# F1 Score: 0.835
# Accuracy: 0.844
