# %%
from ipynb.fs.full.ParkingSpaceDetector import *
import random
import glob

path = 'E:\\OneDrive - UNIVERSIDAD DE HUELVA\TFG\PKLot\PKLot\PKLot\\UFPR05'

files = glob.glob(path+ '/**/*.jpg', recursive=True)            # Get all images in path
selected_files = random.choices(files, k=1)    # Select n random images from dataset

# %%
params =  DetectionParams((9,9), 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 33, 9, 3, 20,vacant_threshold=0.25, show_imshow=True)
confusion_matrix, real, predicted = detect_batch(selected_files, params, True, False)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)
# Out:
# 1/1:  E:\OneDrive - UNIVERSIDAD DE HUELVA\TFG\PKLot\PKLot\PKLot\UFPR05\Cloudy\2013-03-13\2013-03-13_07_25_01.jpg
# ERROR PREDICTED vacant: False
# Pixel count: 1408
# Area: 4779.0 k=0.29462230592174093
# ---------------------------------
# ERROR PREDICTED vacant: True
# Pixel count: 1098
# Area: 5016.0 k=0.21889952153110048
# ---------------------------------
# ERROR PREDICTED vacant: False
# Pixel count: 947
# Area: 3662.0 k=0.258601856908793
# ---------------------------------
# ERROR PREDICTED vacant: False
# Pixel count: 825
# Area: 2798.0 k=0.2948534667619728
# ---------------------------------
# ERROR PREDICTED vacant: True
# Pixel count: 1504
# Area: 6177.5 k=0.24346418454067179
# ---------------------------------
# ERROR PREDICTED vacant: True
# Pixel count: 629
# Area: 3650.5 k=0.17230516367620874
# ---------------------------------
# ERROR PREDICTED vacant: True
# Pixel count: 623
# Area: 3153.5 k=0.19755826859045506
# ---------------------------------
# Precision: 0.733
# Recall: 0.786
# F1 Score: 0.759
# Accuracy: 0.825
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\VCTOR~1\AppData\Local\Temp/ipykernel_5008/1469531785.py in <module>
#       1 params =  DetectionParams((9,9), 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 33, 9, 3, 20,vacant_threshold=0.25, show_imshow=True)
# ----> 2 confusion_matrix, real, predicted = detect_batch(selected_files, params, True, False)
#       3 precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
#WITHOUT GAUSSIAN_BLUR
# params = DetectionParams(None, 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 33, 9, 3, 20) # UPR05
params =  DetectionParams(None, 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 33, 9, 3, 20,vacant_threshold=0.24)
confusion_matrix, real, predicted = process_batch(selected_files, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)
# Out:
# Processing 415 files with 12 cores
# 100%|██████████| 415/415 [01:47<00:00,  3.84it/s]
# Precision: 0.889
# specificity: 0.933
# Recall: 0.761
# F1 Score: 0.820
# Accuracy: 0.862

# %%
params =  DetectionParams((3,3), 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 33, 9, 3, 20,vacant_threshold=0.24)
confusion_matrix, real, predicted = process_batch(selected_files, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)
# Out:
# Processing 415 files with 12 cores
# 100%|██████████| 415/415 [01:22<00:00,  5.05it/s]
# Precision: 0.876
# specificity: 0.920
# Recall: 0.801
# F1 Score: 0.837
# Accuracy: 0.871

# %%
params =  DetectionParams((5,5), 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 33, 9, 3, 20,vacant_threshold=0.24)
confusion_matrix, real, predicted = process_batch(selected_files, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)
# Out:
# Processing 415 files with 12 cores
# 100%|██████████| 415/415 [01:06<00:00,  6.20it/s]
# Precision: 0.866
# specificity: 0.907
# Recall: 0.845
# F1 Score: 0.855
# Accuracy: 0.882

# %%
params =  DetectionParams((7,7), 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 33, 9, 3, 20,vacant_threshold=0.24)
confusion_matrix, real, predicted = process_batch(selected_files, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)
# Out:
# Processing 415 files with 12 cores
# 100%|██████████| 415/415 [00:53<00:00,  7.76it/s]
# Precision: 0.845
# specificity: 0.883
# Recall: 0.904
# F1 Score: 0.874
# Accuracy: 0.892

# %%
params =  DetectionParams((9,9), 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 33, 9, 3, 20,vacant_threshold=0.24)
confusion_matrix, real, predicted = process_batch(selected_files, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)
# Out:
# Processing 415 files with 12 cores
# 100%|██████████| 415/415 [00:44<00:00,  9.34it/s]
# Precision: 0.826
# specificity: 0.860
# Recall: 0.939
# F1 Score: 0.879
# Accuracy: 0.893

# %%
params =  DetectionParams((15,15), 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 33, 9, 3, 20,vacant_threshold=0.24)
confusion_matrix, real, predicted = process_batch(selected_files, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)
# Out:
# Processing 415 files with 12 cores
# 100%|██████████| 415/415 [00:28<00:00, 14.74it/s]
# Precision: 0.725
# specificity: 0.735
# Recall: 0.986
# F1 Score: 0.836
# Accuracy: 0.839
