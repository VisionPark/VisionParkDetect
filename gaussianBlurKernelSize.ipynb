# %%
from ipynb.fs.full.ParkingSpaceDetector import *
import random
import glob

path = 'E:\\OneDrive - UNIVERSIDAD DE HUELVA\TFG\PKLot\PKLot\PKLot\\UFPR05'

files = glob.glob(path+ '/**/*.jpg', recursive=True)            # Get all images in path
selected_files = random.choices(files, k=1)    # Select n random images from dataset

#Define global params for each parking
PARAMS_UFPR04 = DetectionParams((5, 5), 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 29, 8, 3, 23, vacant_threshold=0.26)  # UFPR04
PARAMS_UFPR05 =  DetectionParams((5,5), 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 33, 9, 3, 20,vacant_threshold=0.24) # UPR05
PARAMS_PUCPR = DetectionParams((5,5), 0, cv.ADAPTIVE_THRESH_GAUSSIAN_C, 27, 7, 3, 85, vacant_threshold=0.26) # PUCPR

# Data columns
parking_total = list()
precision_total = list()  # Preicisón: Tasa de TP, lo bien que predice hueco libre sin obtener falsos positivos
specificity_total = list() # Especificdad: Tasa de TN, 
recall_total = list()     # Sensibilidad: la proporción de huecos libres que detectan y no se le escapan
f1_total = list()
accuracy_total = list()

row_names = list()

def gaussian_blur_kernel_size_test(parking_name, params:DetectionParams):
    path = 'E:\\Documents\\PKLot\\PKLot\\PKLot\\PKLot\\'+parking_name
    files = glob.glob(path + '/**/*.jpg', recursive=True)
    selected_files = random.choices(files, k=int(len(files)/10))
    return process_batch(selected_files, params)

# %% [markdown]
# ## UFPR04

# %% [markdown]
# ### Without gaussian blur

# %%
parking = "UFPR04"
params = PARAMS_UFPR04
params.gb_k = None

confusion_matrix, real, predicted = gaussian_blur_kernel_size_test(parking, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)

precision_total.append(precision)
specificity_total.append(specificity)
recall_total.append(recall)
f1_total.append(f1)
accuracy_total.append(accuracy)
row_names.append(f"{parking} None")
# Out:
# Processing 379 files with 12 cores
# 100%|██████████| 379/379 [02:19<00:00,  2.72it/s]
# Precision: 0.918
# specificity: 0.917
# Recall: 0.783
# F1 Score: 0.845
# Accuracy: 0.844

# %% [markdown]
# ### (3,3)

# %%
parking = "UFPR04"
params = PARAMS_UFPR04
params.gb_k = (3,3)

confusion_matrix, real, predicted = gaussian_blur_kernel_size_test(parking, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)

precision_total.append(precision)
specificity_total.append(specificity)
recall_total.append(recall)
f1_total.append(f1)
accuracy_total.append(accuracy)
row_names.append(f"{parking} (3,3)")
# Out:
# Processing 379 files with 12 cores
# 100%|██████████| 379/379 [01:51<00:00,  3.41it/s]
# Precision: 0.921
# specificity: 0.914
# Recall: 0.817
# F1 Score: 0.866
# Accuracy: 0.860

# %% [markdown]
# ### (5,5)

# %%
parking = "UFPR04"
params = PARAMS_UFPR04
params.gb_k = (5,5)

confusion_matrix, real, predicted = gaussian_blur_kernel_size_test(parking, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)

precision_total.append(precision)
specificity_total.append(specificity)
recall_total.append(recall)
f1_total.append(f1)
accuracy_total.append(accuracy)
row_names.append(f"{parking} (5,5)")
# Out:
# Processing 379 files with 12 cores
# 100%|██████████| 379/379 [01:35<00:00,  3.96it/s]
# Precision: 0.904
# specificity: 0.916
# Recall: 0.842
# F1 Score: 0.872
# Accuracy: 0.880

# %% [markdown]
# ### (7,7)

# %%
parking = "UFPR04"
params = PARAMS_UFPR04
params.gb_k = (7,7)

confusion_matrix, real, predicted = gaussian_blur_kernel_size_test(parking, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)

precision_total.append(precision)
specificity_total.append(specificity)
recall_total.append(recall)
f1_total.append(f1)
accuracy_total.append(accuracy)
row_names.append(f"{parking} (7,7)")
# Out:
# Processing 379 files with 12 cores
# 100%|██████████| 379/379 [01:16<00:00,  4.95it/s]
# Precision: 0.919
# specificity: 0.897
# Recall: 0.893
# F1 Score: 0.906
# Accuracy: 0.895

# %% [markdown]
# ### (9,9)

# %%
parking = "UFPR04"
params = PARAMS_UFPR04
params.gb_k = (9,9)

confusion_matrix, real, predicted = gaussian_blur_kernel_size_test(parking, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)

precision_total.append(precision)
specificity_total.append(specificity)
recall_total.append(recall)
f1_total.append(f1)
accuracy_total.append(accuracy)
row_names.append(f"{parking} (9,9)")
# Out:
# Processing 379 files with 12 cores
# 100%|██████████| 379/379 [01:05<00:00,  5.76it/s]
# Precision: 0.892
# specificity: 0.878
# Recall: 0.926
# F1 Score: 0.909
# Accuracy: 0.903

# %% [markdown]
# ### (15,15)

# %%
parking = "UFPR04"
params = PARAMS_UFPR04
params.gb_k = (15,15)

confusion_matrix, real, predicted = gaussian_blur_kernel_size_test(parking, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)

precision_total.append(precision)
specificity_total.append(specificity)
recall_total.append(recall)
f1_total.append(f1)
accuracy_total.append(accuracy)
row_names.append(f"{parking} (15,15)")
# Out:
# Processing 379 files with 12 cores
# 100%|██████████| 379/379 [00:43<00:00,  8.71it/s]
# Precision: 0.812
# specificity: 0.745
# Recall: 0.986
# F1 Score: 0.891
# Accuracy: 0.872

# %% [markdown]
# ## UFPR05

# %% [markdown]
# ### Without gaussian blur

# %%
parking = "UFPR05"
params = PARAMS_UFPR05
params.gb_k = None

confusion_matrix, real, predicted = gaussian_blur_kernel_size_test(parking, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)

precision_total.append(precision)
specificity_total.append(specificity)
recall_total.append(recall)
f1_total.append(f1)
accuracy_total.append(accuracy)
row_names.append(f"{parking} None")
# Out:
# Processing 415 files with 12 cores
# 100%|██████████| 415/415 [01:53<00:00,  3.66it/s]
# Precision: 0.883
# specificity: 0.931
# Recall: 0.766
# F1 Score: 0.820
# Accuracy: 0.864

# %% [markdown]
# ### (3,3)

# %%
parking = "UFPR05"
params = PARAMS_UFPR05
params.gb_k = (3,3)

confusion_matrix, real, predicted = gaussian_blur_kernel_size_test(parking, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)

precision_total.append(precision)
specificity_total.append(specificity)
recall_total.append(recall)
f1_total.append(f1)
accuracy_total.append(accuracy)
row_names.append(f"{parking} (3,3)")
# Out:
# Processing 415 files with 12 cores
# 100%|██████████| 415/415 [01:24<00:00,  4.92it/s]
# Precision: 0.863
# specificity: 0.916
# Recall: 0.799
# F1 Score: 0.830
# Accuracy: 0.869

# %% [markdown]
# ### (5,5)

# %%
parking = "UFPR05"
params = PARAMS_UFPR05
params.gb_k = (5,5)

confusion_matrix, real, predicted = gaussian_blur_kernel_size_test(parking, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)

precision_total.append(precision)
specificity_total.append(specificity)
recall_total.append(recall)
f1_total.append(f1)
accuracy_total.append(accuracy)
row_names.append(f"{parking} (5,5)")
# Out:
# Processing 415 files with 12 cores
# 100%|██████████| 415/415 [01:07<00:00,  6.16it/s]
# Precision: 0.875
# specificity: 0.904
# Recall: 0.843
# F1 Score: 0.858
# Accuracy: 0.877

# %% [markdown]
# ### (7,7)

# %%
parking = "UFPR05"
params = PARAMS_UFPR05
params.gb_k = (7,7)

confusion_matrix, real, predicted = gaussian_blur_kernel_size_test(parking, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)

precision_total.append(precision)
specificity_total.append(specificity)
recall_total.append(recall)
f1_total.append(f1)
accuracy_total.append(accuracy)
row_names.append(f"{parking} (7,7)")
# Out:
# Processing 415 files with 12 cores
# 100%|██████████| 415/415 [00:53<00:00,  7.74it/s]
# Precision: 0.856
# specificity: 0.885
# Recall: 0.909
# F1 Score: 0.882
# Accuracy: 0.895

# %% [markdown]
# ### (9,9)

# %%
parking = "UFPR05"
params = PARAMS_UFPR05
params.gb_k = (9,9)

confusion_matrix, real, predicted = gaussian_blur_kernel_size_test(parking, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)

precision_total.append(precision)
specificity_total.append(specificity)
recall_total.append(recall)
f1_total.append(f1)
accuracy_total.append(accuracy)
row_names.append(f"{parking} (9,9)")
# Out:
# Processing 415 files with 12 cores
# 100%|██████████| 415/415 [00:43<00:00,  9.56it/s]
# Precision: 0.808
# specificity: 0.848
# Recall: 0.948
# F1 Score: 0.873
# Accuracy: 0.888

# %% [markdown]
# ### (15,15)

# %%
parking = "UFPR05"
params = PARAMS_UFPR05
params.gb_k = (15,15)

confusion_matrix, real, predicted = gaussian_blur_kernel_size_test(parking, params)
precision, specificity, recall, f1, accuracy = show_confusion_matrix(confusion_matrix, real, predicted)

precision_total.append(precision)
specificity_total.append(specificity)
recall_total.append(recall)
f1_total.append(f1)
accuracy_total.append(accuracy)
row_names.append(f"{parking} (15,15)")
# Out:
# Processing 415 files with 12 cores
# 100%|██████████| 415/415 [00:35<00:00, 11.68it/s]
# Precision: 0.732
# specificity: 0.734
# Recall: 0.987
# F1 Score: 0.840
# Accuracy: 0.841

# %% [markdown]
# ## Total results

# %%
import pandas as pd

data = {
  "precision": precision_total,
  "specificity": specificity_total,
  "recall": recall_total,
  "f1": f1_total,
  "accuracy": accuracy_total
}

df = pd.DataFrame(data, index = row_names)

print(df.round(3))
# Out:
#                 precision  specificity    recall        f1  accuracy
# UFPR04 None      0.917679     0.917176  0.782659  0.844808  0.844373
# UFPR04 (3,3)     0.921374     0.913774  0.817214  0.866174  0.860390
# UFPR04 (5,5)     0.904365     0.916388  0.842028  0.872084  0.880377
# UFPR04 (7,7)     0.919244     0.896854  0.893155  0.906012  0.894753
# UFPR04 (9,9)     0.891735     0.877745  0.926379  0.908727  0.903076
# UFPR04 (15,15)   0.812251     0.744575  0.986057  0.890755  0.872186
# UFPR05 None      0.882728     0.931240  0.765532  0.819963  0.864398
# UFPR05 (3,3)     0.863213     0.916191  0.798730  0.829720  0.869398
# UFPR05 (5,5)     0.874824     0.903854  0.842749  0.858487  0.876747
# UFPR05 (7,7)     0.856352     0.884705  0.909320  0.882042  0.895301
# UFPR05 (9,9)     0.808001     0.847977  0.948407  0.872592  0.888434
# UFPR05 (15,15)   0.731710     0.733981  0.986919  0.840366  0.841145
